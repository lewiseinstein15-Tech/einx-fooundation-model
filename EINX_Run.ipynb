# %% [markdown]
# # EINX v2 — Train + Test
#
# 1. Runtime → Change runtime type → T4 GPU
# 2. Click Play below
# 3. Wait ~8 min
# 4. Copy results

# %%
# Step 1: Download the script
import urllib.request
url = 'https://raw.githubusercontent.com/lewiseinstein15-Tech/einx-fooundation-model/main/einx_standalone.py'
urllib.request.urlretrieve(url, 'einx_standalone.py')
print('Downloaded!')

# %%
# Step 2: Install deps + Run the script
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'pydantic', 'pyyaml', 'requests', 'tqdm'], check=True)
exec(open('einx_standalone.py').read())
