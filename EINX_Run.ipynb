# %% [markdown]
# # EINX — Just Click Run
#
# 1. **Runtime → Change runtime type → T4 GPU**
# 2. **Click the Play button below**
# 3. Wait ~5 minutes
# 4. See results

# %%
# Download the script and run it — that's it.
# !wget -q https://raw.githubusercontent.com/lewiseinstein15-Tech/einx-fooundation-model/main/einx_standalone.py -O einx_standalone.py
# !python einx_standalone.py
